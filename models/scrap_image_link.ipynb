# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import urllib.request

# %%
def read_data(): 
    data = pd.read_excel("../data/recommendartion_data/finalIndonesia_data.xlsx")
    return data
def get_image_link(data : pd.DataFrame, attr : list, class_atr: str, iter = 1):
    arr = []
    for image_mame in data.loc[:100, 'nama_makanan']: 
        try: 
            url = requests.get(f'https://www.bing.com/images/search?q={image_mame}&form=HDRSC3')
            soup = BeautifulSoup(url.content, 'lxml')
            get_image_link = soup.find(name = attr[0], attrs={"class" : class_atr})
            get_href = get_image_link.find(attr[1], href=True)['href']
            final = "https://www.bing.com/" + get_href
            arr.append(final)
        except Exception as e: 
            print(f'error : {e} or image tag not detected')
    return arr

def get_second_links(data_link):
    arr_image_link = []

    for link in data_link:
        try: 
            url = requests.get(link)
            soup = BeautifulSoup(url.content, 'lxml') 
     
            get_image_link = soup.find_all(name = "div",id = "b_content")
          
            if get_image_link: 
  
                for attributes in str(get_image_link).split(":"):
                    for j in str(attributes).split(":"):
                        # print(j)
                        if "ImgDet" and ".mm.bing.net/th/id/OIP." in j:
                            arr_image_link.append("https:" + j.replace("fhs", "").replace('"' , "").split(",")[0])
                         
        except Exception as e: 
            print(f'error : {e} or image tag not detected')
    return arr_image_link


# second_get = get_image_link()

# %%
data = read_data()
first_get = get_image_link(data, attr=["div", "a"], class_atr= "infopt")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 2
#       1 data = read_data()
# ----> 2 first_get = get_image_link(data, attr=["div", "a"], class_atr= "infopt")
#
# Cell In[40], line 8, in get_image_link(data, attr, class_atr, iter)
#       6 for image_mame in data.loc[:, 'nama_makanan']:
#       7     try:
# ----> 8         url = requests.get(f'https://www.bing.com/images/search?q={image_mame}&form=HDRSC3')
#       9         soup = BeautifulSoup(url.content, 'lxml')
#      10         get_image_link = soup.find(name = attr[0], attrs={"class" : class_atr})
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
print(first_get)
# Out:
# ['https://www.bing.com//images/search?view=detailV2&ccid=S8VCtJBE&id=8693B4E43A6E3FDDB051355536E7E14804034905&thid=OIP.S8VCtJBErqSZTPytX1YE2QHaE7&mediaurl=https%3a%2f%2f4.bp.blogspot.com%2f-_vtav3uejiY%2fVYJx05R4TzI%2fAAAAAAAAAxg%2froOC0RLptv4%2fs1600%2frendang%252Bdaging.jpg&exph=1066&expw=1600&q=daging+rendang&simid=608026469189488019&FORM=IRPRST&ck=A44DB2FC1D20BB8004B9265B0D170372&selectedIndex=0&itb=0', 'https://www.bing.com//images/search?view=detailV2&ccid=AkfOpy3l&id=34340859B2C2DF5EAF7FBBBC22661D22A9D479F9&thid=OIP.AkfOpy3l_ih3Yqrbg4D4SwHaIB&mediaurl=https%3a%2f%2fcdn-brilio-net.akamaized.net%2fnews%2f2022%2f02%2f20%2f223411%2f1672778-terong-pedas-.jpg&exph=813&expw=750&q=Terong+Pedas+(Terong+Balado)&simid=608037150772696914&FORM=IRPRST&ck=13E946569462EA721E7B42BE1ADA139D&selectedIndex=0&itb=0', 'https://www.bing.com//images/search?view=detailV2&ccid
selectedIndex=0&itb=0', 'https://www.bing.com//images/search?view=detailV2&ccid=7W9K1iYT&id=FD5CF5E65753DEB1824C77D94FA41FBF9D910F91&thid=OIP.7W9K1iYTBTNwcDgqarB_XAAAAA&mediaurl=https%3a%2f%2fwww.reseppedia.com%2fstorage%2fupload%2fAyam_Bakar_Pedas_Manis.jpg&exph=296&expw=474&q=Barbeque+Ayam+Pedas+Indonesia+(Ayam+Bakar+Pedas)&simid=608040346175349041&FORM=IRPRST&ck=9C177BE06BF504DEE6FD05E27B616088&selectedIndex=0&itb=0', 'https://www.bing.com//images/search?view=detailV2&ccid=7gUaV9HU&id=CEA74B52E6442DEA8837CEC49C70D48C259FBF3E&thid=OIP.7gUaV9HUg036bOxOGxSkfwHaEK&mediaurl=https%3a%2f%2fcdn-2.tstatic.net%2ftribunnews%2ffoto%2fbank%2fimages%2fresep-sate-daging-sapi-dan-kambing-2972020.jpg&exph=393&expw=700&q=Sate+Daging+Sapi+ala+Jawa&simid=608056040022813282&FORM=IRPRST&ck=F1FB63763A5E3C5B22B5AF05D82DDA25&selectedIndex=0&itb=0', 'https://www.bing.com//images/search?view=detailV2&ccid=TyIa4px3&id=F7A901028122F1CFA34920288A706ECCBDB637E8&thid=OIP.TyIa4px3cM28JAtQiqVPfAHaFj&mediaurl=https%3a%2f%2fi.pinimg.com%2foriginals%2faf%2fa0%2f26%2fafa026efd3563f897a885ab64cc82ae0.jpg&exph=1944&expw=2592&q=Sate+Indonesia+(Kebab+Daging)&simid=608051006305759834&FORM=IRPRST&ck=B7B207C1A06D2EC5D905843591CA ...

# %%
second_get = get_second_links(first_get)

# %%
second_get
# Out:
# ['https://tse4.mm.bing.net/th/id/OIP.S8VCtJBErqSZTPytX1YE2QHaE7?pid=ImgDet',
#  'https://tse4.mm.bing.net/th/id/OIP.AkfOpy3l_ih3Yqrbg4D4SwHaIB?pid=ImgDet',
#  'https://tse3.mm.bing.net/th/id/OIP.hKG8ipuAlIS43OgHHJ9sowHaJQ?pid=ImgDet',
#  'https://tse2.mm.bing.net/th/id/OIP.ybYLWv-BJAhUcDvIrzAunQHaE8?pid=ImgDet',
#  'https://tse1.mm.bing.net/th/id/OIP.HoviYkueLam61exCuYiFbwHaFj?pid=ImgDet',
#  'https://tse3.mm.bing.net/th/id/OIP.Iv3t98oY9xefHJtxitBa8gHaE8?pid=ImgDet',
#  'https://tse2.mm.bing.net/th/id/OIP.x8_9M077BDEiFjS2xh8OUgHaHW?pid=ImgDet',
#  'https://tse1.mm.bing.net/th/id/OIP.7W9K1iYTBTNwcDgqarB_XAAAAA?pid=ImgDet',
#  'https://tse4.mm.bing.net/th/id/OIP.7gUaV9HUg036bOxOGxSkfwHaEK?pid=ImgDet',
#  'https://tse3.mm.bing.net/th/id/OIP.TyIa4px3cM28JAtQiqVPfAHaFj?pid=ImgDet',
#  'https://tse1.mm.bing.net/th/id/OIP.gFlPKt3BvMQlEpAwmwXC9wHaFj?pid=ImgDet']
