# %%
import tensorflow  as tf
# import tensorflow_recommenders as tfrs
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import random

# %%
# read the data
food_data = pd.read_excel("./data/recommendartion_data/finalIndonesia_data.xlsx")
food_data.drop("Unnamed: 0", inplace = True, axis = 1)
# replace the ID with int value 
for i in range(len(food_data)): 
    food_data.loc[i, 'resep_id'] = i + 1
food_data.head()
# Out:
#   resep_id                   nama_makanan  \
# 0        1                 daging rendang
# 1        2   Terong Pedas (Terong Balado)
# 2        3  Cara Membuat Sate Daging Sapi
# 3        4            Sate Babi Indonesia
# 4        5             Udang Sambal Pedas
#
#                                            nama_gizi  \
# 0  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 1  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 2  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 3  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 4  Protein (g), Energi (kKal), Karbohidrat (g), T...
#
#                         kandungan_nutrisi   kategori
# 0  228.6072, 3442.2196, 126.463, 227.5751  Indonesia
# 1      2.4267, 698.2169, 26.8406, 68.3922  Indonesia
# 2   193.938, 2396.4036, 74.3372, 145.9531  Indonesia
# 3    179.1272, 1647.3999, 47.8303, 84.596  Indonesia
# 4    84.9721, 1067.8366, 49.9121, 62.3498  Indonesia

# %%
# read the dataset
data_ratings = pd.read_csv("./data/recommendartion_data/ratings.csv")
#  read the ratings
data_ratings = data_ratings.rename(columns={"movieId" : "resep_id"})
# drope labels that are not really used 
data_ratings.drop(labels = 'timestamp', inplace=True, axis = 1)
data_ratings.head()
# Out:
#    userId  resep_id  rating
# 0       1         1     4.0
# 1       1         3     4.0
# 2       1         6     4.0
# 3       1        47     5.0
# 4       1        50     5.0

# %%
# merge the ratings and food_data
final_data = food_data.merge(data_ratings, how = "inner",  on = "resep_id").sort_values(by = "userId")
# final_data = pd.concat([data_ratings, food_data], axis=0)
final_data
# Out:
#       resep_id                                       nama_makanan  \
# 0            1                                     daging rendang
# 7860       296  Rendang Padang - Kari Daging Sapi Indonesia (S...
# 6853       260                                       Sayur Taucho
# 6368       235      Kari Daging Sapi Indonesia Dengan Nasi Kelapa
# 6192       231                          Tenderloin Babi Indonesia
# ...        ...                                                ...
# 8166       296  Rendang Padang - Kari Daging Sapi Indonesia (S...
# 214          1                                     daging rendang
# 4436       153  Pancit Guisado Filipina (Mie Goreng dengan dag...
# 10347      356                         Kari Daging Sapi Indonesia
# 1678        32                              Nasi Goreng Indonesia
#
#                                                nama_gizi  \
# 0      Protein (g), Energi (kKal), Karbohidrat (g), T...
# 7860   Protein (g), Energi (kKal), Karbohidrat (g), T...
# 6853   Protein (g), Energi (kKal), Karbohidrat (g), T...
# 6368   Protein (g), Energi (kKal), Karbohidrat (g), T...
# 6192   Protein (g), Energi (kKal), Karbohidrat (g), T...
# ...                                                  ...
# 8166   Protein (g), Energi (kKal), Karbohidrat (g), T...
# 214    Protein (g), Energi (kKal), Karbohidrat (g), T...
# 4436   Protein (g), Energi (kKal), Karbohidrat (g), T...
# 10347  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 1678   Protein (g), Energi (kKal), Karbohidrat (g), T...
#
#                                 kandungan_nutrisi   kategori  userId  rating
# 0          228.6072, 3442.2196, 126.463, 227.5751  Indonesia       1     4.0
# 7860         278.9743, 2115.1029, 36.9886, 93.694  Indonesia       1     3.0
# 6853   2271.5546, 28266.7279, 3916.4228, 865.7599  Indonesia       1     5.0
# 6368         171.796, 1794.887, 61.2606, 102.0414  Indonesia       1     4.0
# 6192            98.4191, 598.257, 9.9387, 16.5197  Indonesia       1     5.0
# ...                                           ...        ...     ...     ...
# 8166         278.9743, 2115.1029, 36.9886, 93.694  Indonesia     610     5.0
# 214        228.6072, 3442.2196, 126.463, 227.5751  Indonesia     610     5.0
# 4436       164.0411, 2357.0216, 368.3591, 23.2857  Indonesia     610     3.0
# 10347     139.2323, 3464.0288, 379.4381, 159.3442  Indonesia     610     3.0
# 1678        203.0239, 1439.0602, 17.7117, 59.9104  Indonesia     610     4.5
#
# [10461 rows x 7 columns]

# %%
#  save the final file
final_data.to_excel("./data/recommendartion_data/final_data.xlsx")

# %%
# read the data
df = pd.read_excel("./data/recommendartion_data/final_data.xlsx", index_col=0)
df.head(10)
# Out:
#       resep_id                                       nama_makanan  \
# 0            1                                     daging rendang
# 7860       296  Rendang Padang - Kari Daging Sapi Indonesia (S...
# 6853       260                                       Sayur Taucho
# 6368       235      Kari Daging Sapi Indonesia Dengan Nasi Kelapa
# 6192       231                          Tenderloin Babi Indonesia
# 5940       223                                    Drum Ayam Manis
# 5853       216   Salad Indonesia KD Lang Dengan Saus Kacang Pedas
# 4722       163  Mission Street Marinasi Bengkuang & Acar Jalapeno
# 4458       157                      Perkedel Resep Asli Indonesia
# 4254       151                                     Sambal Belacan
#
#                                               nama_gizi  \
# 0     Protein (g), Energi (kKal), Karbohidrat (g), T...
# 7860  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 6853  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 6368  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 6192  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 5940  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 5853  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 4722  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 4458  Protein (g), Energi (kKal), Karbohidrat (g), T...
# 4254  Protein (g), Energi (kKal), Karbohidrat (g), T...
#
#                                kandungan_nutrisi   kategori  userId  rating
# 0         228.6072, 3442.2196, 126.463, 227.5751  Indonesia       1     4.0
# 7860        278.9743, 2115.1029, 36.9886, 93.694  Indonesia       1     3.0
# 6853  2271.5546, 28266.7279, 3916.4228, 865.7599  Indonesia       1     5.0
# 6368        171.796, 1794.887, 61.2606, 102.0414  Indonesia       1     4.0
# 6192           98.4191, 598.257, 9.9387, 16.5197  Indonesia       1     5.0
# 5940       956.1837, 10441.735, 4.7206, 701.5553  Indonesia       1     3.0
# 5853         22.4818, 739.6693, 36.6404, 62.2456  Indonesia       1     5.0
# 4722         98.5908, 944.2484, 112.0988, 3.3785  Indonesia       1     5.0
# 4458       4258.15, 128869.6, 26037.405, 586.305  Indonesia       1     5.0
# 4254         40.127, 1177.9165, 275.9378, 1.6212  Indonesia       1     5.0

# %%
df.dtypes
# Out:
# resep_id               int64
# nama_makanan          object
# nama_gizi             object
# kandungan_nutrisi     object
# kategori              object
# userId                 int64
# rating               float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# resep_id             0
# nama_makanan         0
# nama_gizi            0
# kandungan_nutrisi    0
# kategori             0
# userId               0
# rating               0
# dtype: int64

# %%
# top 10 ratings food 
data_grouped = final_data.groupby("nama_makanan")['rating'].mean().sort_values(ascending = False)[:10]
data_grouped
# Out:
# nama_makanan
# Tempe Manis dan Pedas                                    5.000000
# Pancake Pisang, Resep Wayan                              5.000000
# Perkedel Indonesia                                       5.000000
# Kari Ayam Kelapa (kari ayam dengan kelapa panggang)      4.500000
# Ayam Bakar Indonesia                                     4.429022
# Salad Indonesia Kd Lang                                  4.375000
# Perkedel Djagung ( Udang dan Jagung Goreng Indonesia)    4.307692
# Fillet Daging Sapi dalam Kelapa                          4.293103
# Sup Wortel Indonesia                                     4.250000
# Bahmi Goreng Indonesia                                   4.237745
# Name: rating, dtype: float64

# %%
EMBEDDING_SIZE = 100
# IMPORTANT : pleae read the documentation for register the custom class model to avoid error
# documentation for custom class : https://colab.research.google.com/github/keras-team/keras-io/blob/master/guides/ipynb/serialization_and_saving.ipynb#config_methods
# clear the previoues custom objects
keras.saving.get_custom_objects().clear()
# register the custom layer 
@keras.saving.register_keras_serializable(package="RecomendationLayer")
class RecommenderNet(tf.keras.Model):
    def __init__(self, num_users, num_fooods, embedding_size, **kwargs):
        super().__init__(**kwargs)
        self.num_users = num_users
        self.num_fooods = num_fooods
        self.embedding_size = embedding_size
        # first hidden layer
        self.dense1 = tf.keras.layers.Dense(128, activation="relu")
        #  second hidden layer
        self.dense2 = tf.keras.layers.Dense(64, activation="relu")
        # third hidden layer
        self.dense3 = tf.keras.layers.Dense(1, activation="sigmoid")
        # embedding layer for user vector
        self.user_embedding = tf.keras.layers.Embedding(
            num_users,
            # embedding size = user vector
            embedding_size,
            # set the weight to standart normalization and thhe output shape of array will sane like num_users.embedidng size
            embeddings_initializer="he_normal",
            embeddings_regularizer=tf.keras.regularizers.l2(1e-6),
        )
        # adding user_bias
        self.user_bias = tf.keras.layers.Embedding(num_users, 1)
        # embedding layer for food vector
        self.food_embedding = tf.keras.layers.Embedding(
            num_fooods,
            embedding_size,
            # set the weight to standart normalization and thhe output shape of array will sane like num_users.embedidng size
            embeddings_initializer="he_normal",
            embeddings_regularizer= tf.keras.regularizers.l2(1e-6),
        )
        self.food_bias = tf.keras.layers.Embedding(num_fooods, 1)
    
    def call(self, inputs):
        # user vector
        user_vector = self.user_embedding(inputs[:, 0])
        # user bias
        user_bias = self.user_bias(inputs[:, 0])
        food_vector = self.food_embedding(inputs[:, 1])
        food_bias = self.food_bias(inputs[:, 1])
        # set the dfimension to 2D dimensio
        dot_user_movie = tf.tensordot(user_vector, food_vector, 2)
        # Add all the components (including bias)
        x = dot_user_movie + user_bias + food_bias
        #  first dense layer
        dense_layer1 = self.dense1(x)
        dense_layer2 = self.dense2(dense_layer1)
        # return the output layer
        return self.dense3(dense_layer2)
    
    #  adding some config
    def get_config(self):
        #  call the main config
        config = super().get_config()
        # update to config, to initialize the self.num_users = num_users, self.num_fooods = num_fooods self.embedding_size = embedding_size
        config.update({
            # all the configuration forr new config
            "num_users": self.num_users,
            "num_fooods": self.num_fooods,
            "embedding_size": self.embedding_size,
        })
        #  return the config
        return config
    
    # for class method
    @classmethod
    def from_config(cls, config):
        return  cls( **config)

# %%
# for dataframe use apply
def get_train_test_data(df : pd.DataFrame): 
    x = df[['userId', 'resep_id']].values
    # train len
    train_len = int(0.9 * df.shape[0])
    max_rating = max(df["rating"])
    # normalization
    y = df['rating'].apply(lambda x: x / max_rating).values
    #  train and test dataset
    x_train, x_test, y_train, y_test = (
        x[:train_len],
        x[train_len:],
        y[:train_len],
        y[train_len:],
    )
    return x_train, x_test, y_train, y_test 
# function for getting length of unique user id and foo id
def get_food_user_len(df : pd.DataFrame): 
    #  len user
    len_user = len(df['userId'].unique().tolist())
    # len nama makanan
    len_nama_makanan = len(df['resep_id'].unique().tolist())
    return len_user, len_nama_makanan

def create_and_train_model(x_train, x_test, y_train, y_test, len_user, len_nama_makanan): 
    # call the model class
    model = RecommenderNet(len_user, len_nama_makanan, EMBEDDING_SIZE)
    # compile model 
    model.compile(
        # loss function
        loss=tf.keras.losses.BinaryCrossentropy(),
        # optimizer
        optimizer='adam',
        # metrics
        metrics = [tf.keras.metrics.MeanSquaredError()]
    )
    # start to train the model 
    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=64,
        epochs=100,
        verbose=1,
        validation_data=(x_test, y_test),

    )
    return model, history 

def display_predictiom(model, x_test, y_test, nums = 10):
    # the prediction
    pred = model.predict(x_test)
    # loop for model predcition 
    for i in range(nums): 
        print(f'predict : {pred[i] * 5.0}')
        print(f'actual : {y_test[i] *  5.0}')
        print('====================================')
    # return to prediction 
    return pred


len_user, len_nama_makanan = get_food_user_len(df)
x_train, x_test, y_train, y_test  = get_train_test_data(df)
model, history = create_and_train_model(x_train, x_test, y_train, y_test, len_user, len_nama_makanan)
model.save("recommendation_model.keras")
# model.save_weights("./recommendation_model.weights.h5")
display_predictiom(model, x_test, y_test, 20)
# Out:
# Epoch 1/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.6380 - mean_squared_error: 0.0630 - val_loss: 0.6316 - val_mean_squared_error: 0.0468
# Epoch 2/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6016 - mean_squared_error: 0.0454 - val_loss: 0.6339 - val_mean_squared_error: 0.0478
# Epoch 3/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6015 - mean_squared_error: 0.0446 - val_loss: 0.6331 - val_mean_squared_error: 0.0475
# Epoch 4/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5991 - mean_squared_error: 0.0443 - val_loss: 0.6286 - val_mean_squared_error: 0.0452
# Epoch 5/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5994 - mean_squared_error: 0.0446 - val_loss: 0.6311 - val_mean_squared_error: 0.0465
# Epoch 6/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6047 - mean_squared_error: 0.0451 - val_loss: 0.6298 - val_mean_squared_error: 0.0459
# Epoch 7/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.
100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5605 - mean_squared_error: 0.0296 - val_loss: 0.6167 - val_mean_squared_error: 0.0409
# Epoch 91/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5611 - mean_squared_error: 0.0291 - val_loss: 0.6147 - val_mean_squared_error: 0.0400
# Epoch 92/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5635 - mean_squared_error: 0.0299 - val_loss: 0.6174 - val_mean_squared_error: 0.0412
# Epoch 93/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5680 - mean_squared_error: 0.0294 - val_loss: 0.6151 - val_mean_squared_error: 0.0402
# Epoch 94/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5642 - mean_squared_error: 0.0293 - val_loss: 0.6154 - val_mean_squared_error: 0.0404
# Epoch 95/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5624 - mean_squared_error: 0.0294 - val_loss: 0.6143 - val_mean_squared_error: 0.0399
# Epoch 96/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5638 - mean_squared_error: 0.0286 - val_loss: 0.6130 - val_mean_squared_error: 0.0392
# Epoch 97/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5627 - mean_squared_error: 0.0294 - val_loss: 0.6132 - val_mean_squared_error: 0.0393
# Epoch 98/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5655 - mean_squared_error: 0.0292 - val_loss: 0.6154 - val_mean_squared_error: 0.0403
# Epoch 99/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5624 - mean_squared_error: 0.0292 - val_loss: 0.6151 - val_mean_squared_error: 0.0402
# Epoch 100/100
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5614 - mean_squared_error: 0.0288 - val_loss: 0.6161 - val_mean_squared_error: 0.0406
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# predict : [4.3123226]
# actual : 3.5
# ====================================
# predict : [4.069217]
# actual : 4.0
# ====================================
# predict : [4.3327465]
# actual : 5.0
# ====================================
# predict : [4.069217]
# actual : 3.5
# ====================================
# predict : [4.143254]
# actual : 2.0
# ====================================
# predict : [4.069217]
# actual : 5.0
# ====================================
# predict : [4.069217]
# actual : 2.0
# ====================================
# predict : [4.045697]
# actual : 4.0
# ====================================
# predict : [4.521023]
# actual : 5.0
# ====================================
# predict : [4.00397]
# actual : 3.5
# ====================================
# predict : [4.5153494]
# actual : 4.0
# ====================================
# predict : [3.796659]
# actual : 4.5
# ====================================
# predict : [3.796659]
# actual : 5.0
# ====================================
# predict : [4.340939]
# actual : 4.0
# ====================================
# predict : [3.8430476]
# actual : 4.0
# ====================================
# predict : [3.8430476]
# actual : 4.0
# ====================================
# predict : [3.5350184]
# actual : 3.0
# ====================================
# predict : [3.4221535]
# actual : 5.0
# ====================================
# predict : [3.1772614]
# actual : 4.5
# ====================================
# predict : [3.5273228]
# actual : 4.0
# ====================================
# array([[0.86246455],
#        [0.8138434 ],
#        [0.86654925],
#        ...,
#        [0.60806787],
#        [0.75747937],
#        [0.8172501 ]], dtype=float32)

# %%
# fig  = plt.figure(figsize=(20, 10))
fig, ax1 = plt.subplots(1, 1, sharey=True, figsize=(15, 8))
ax1.plot([x for x in range(1, 101)], history.history['mean_squared_error'], label = "train mse")
ax1.plot([x for x in range(1, 101)], history.history['val_mean_squared_error'], label = "val mse")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Mse Value')
ax1.set_title("mse and loss")
ax1.legend()
plt.show()

# %%
fig, ax1 = plt.subplots(1, 1, sharey=True, figsize=(15, 8))
ax1.plot([x for x in range(1, 101)], history.history['loss'], label = "train loss")
ax1.plot([x for x in range(1, 101)], history.history['val_loss'], label = "val loss")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('loss value')
ax1.set_title("loss")
ax1.legend()
plt.show()

# %%
# load custom model 
reconstructed_model = keras.models.load_model(
    "./recommendation_model.keras",
    custom_objects={"RecomendationLayer": RecommenderNet}
)
#  dping prediction
print(len(reconstructed_model.predict(x_test)))
# Out:
# WARNING:tensorflow:From c:\Users\Teddy Dharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\core.py:188: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1047

# %%
data2 = pd.read_excel("./data/recommendartion_data/final_data.xlsx")
# read data and remove the duplicate 
data2.drop_duplicates(subset=['resep_id'], inplace = True)
data2.shape
# Out:
# (318, 8)

# %%
def prediction_for_spesific_user(model, df: pd.DataFrame): 
    # random user_id
    user_id = random.randint(a = 9999, b = 99999)
    all_prediction = []
    # recipe_id_uniques = np.unique(df.loc[:, 'resep_id'])
    for i in range(df.shape[0]): 
        print(f'product id : {i}')
        all_prediction.append(model.predict(np.array([[user_id, i]]))[0][0] * 5)
    # this will sort the ratings from higher to lower
    all_prediction = np.argsort(all_prediction)[::-1]
    return all_prediction 

def list_of_recomendation_food(index, df: pd.DataFrame):
    # the final recomendation
    foods = []
    for i in index: 
        foods.append(df.iloc[i]['nama_makanan'])
    return foods

# %%
index = prediction_for_spesific_user(reconstructed_model, data2)
# Out:
# product id : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# product id : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# product id : 30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 31
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 32
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 33
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 34
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 35
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 36
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 37
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 38
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 39
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 41
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 42
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 43
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 44
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 45
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 46
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 47
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 48
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 49
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 51
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 52
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 53
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 54
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 55
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 56
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 57
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 58
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 59
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 61
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 62
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 63
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 65
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 66
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 67
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 68
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 69
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 71
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 72
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 73
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 74
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 77
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 78
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 79
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 80
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 81
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 82
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 83
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 84
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 85
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 86
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 87
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 88
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 89
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 90
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 91
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# product id : 92
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 93
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 94
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 95
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 96
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 97
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# product id : 98
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# product id : 99
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 102
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# product id : 106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 108
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 129
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 131
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 134
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 136
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 137
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 139
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 140
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 141
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 142
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 143
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 146
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 148
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 151
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# product id : 152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 153
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 154
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 158
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 160
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 161
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 163
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# product id : 164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# product id : 165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 168
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 171
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 172
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 173
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 174
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# product id : 176
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 177
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 178
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 182
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 184
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 185
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 186
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 187
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 189
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 190
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 191
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 192
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 193
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 194
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 195
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 196
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 197
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 198
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 199
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 202
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 207
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# product id : 209
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 210
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 211
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 213
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 214
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 215
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 216
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 217
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 218
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 220
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 221
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 222
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 223
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# product id : 224
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 230
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 231
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 232
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 234
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 235
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 236
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 237
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 238
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 240
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 241
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 243
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 244
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 245
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 246
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 248
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 249
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 251
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 252
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 253
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 254
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 255
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 256
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 258
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 259
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 260
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 261
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 262
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 263
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 265
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 268
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 270
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 272
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 273
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 274
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 275
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 276
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 277
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# product id : 278
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# product id : 279
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# product id : 280
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 282
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# product id : 283
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# product id : 284
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 285
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# product id : 286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 288
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 289
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 290
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 291
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 293
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 294
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 295
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 296
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# product id : 297
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 298
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 299
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 302
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 304
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# product id : 306
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 307
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# product id : 309
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 310
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 311
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 312
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# product id : 314
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# product id : 315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# product id : 316
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# product id : 317
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
foods =list_of_recomendation_food(index, data2)
foods
# Out:
# ['Ikan Pedas Indonesia',
#  'Ayam Indonesia Mudah',
#  'Ayam Indonesia',
#  'Sambal Cabai (Saus Cabai Indonesia)',
#  'Perkedel Kentang dan Daging Sapi Indonesia',
#  'Bolu kukus',
#  'Nasi Kuning Gurih',
#  'Saus Barbekyu Indonesia',
#  'Perkedel Djagung ( Udang dan Jagung Goreng Indonesia)',
#  'Kenikmatan Jakarta',
#  'Crock Pot Daging Sapi atau Babi Indonesia',
#  'Sup Mie Ayam Indonesia (Soto Ayam)',
#  'Tahu Mengkilap Dengan Mutiara Sriracha yang Berapi-api',
#  'Sate Ayam Indonesia Dengan Saus Kacang',
#  'Cumi Cumi Smoor (Cumi dengan Saus Tomat dan Cengkih)',
#  'Ayam Pedas Panggang (Ala Padang)',
#  'Nasi Indonesia (gurih)',
#  'Ayam Indonesia Erin',
#  'Kari Nanas Indonesia',
#  'Rendang',
#  'Sup Wortel Indonesia',
#  'Steak Rebus, Gaya Indonesia',
#  'Lapis Legit (Kue Seribu Lapis)',
#  'Soda Gembira (Soda Bahagia)',
#  'Jus Alpokat (Minuman Alpukat khas indonesia)',
#  'Acar Campur (Acar Sayuran)',
#  'Salad Indonesia KD Lang Dengan Saus Kacang Pedas',
#  'Atjar (Salad Kubis Asam Manis)',
#  'Kecap Ala Indonesia IndoCook',
#  'Semur Ayam',
#  'Jeruk Nipis',
#  'Sate Babi Indonesia',
#  'Pilus (Puff Ubi Jalar Indonesia)',
#  'Ayam Bakar Bumbu',
#  'Kaki Domba Panggang',
#  'Udang ala Dayak (Kalimantan)',
#  'Jagung Kari Kacang',
#  'Sate Daging Sapi Indonesia',
#  'Rendang Padang - Kari Daging Sapi Indonesia (Slow Cooker)',
#  'Muffin Kelapa yang Lezat',
#  'Pilaf Nasi Pulau',
#  'Biji Salak - Bola Ketan dengan Saus Kelapa Manis',
#  'Rendang Daging Sapi ala Sumatera',
#  'Pasta Kari ala Indonesia',
#  'sate sapi',
#  'Cap Cai',
#  'Soto Ayam (Sup Ayam Bening Indonesia)',
#  'Sate Udang Indonesia',
#  'Ayam Masak Lambat Indonesia (Ayam Manado)',
#  'Kari Hati',
#  'Tahu Asam Manis Indonesia Dengan Sayuran',
#  'Kari Daging Sapi Rendang Indonesia',
#  'Kuah Titchrah (Hidangan kari Ikan Cair Pedas Aceh yang Pedas)',
#  'Hati Ayam Indonesia',
#  'Celupan Indonesia',
#  'Barbeque Ayam Pedas Indonesia (Ayam Bakar Pedas)',
#  'Ikan Pengawetan Tradisional (Umai)',
#  'Puff Kari Panggang',
#  'Campur Kegilaan Sayuran Indonesia',
#  'Bika Ambon',
#  'Sate Kerang (Kepulauan Ashmore dan Cartier)',
#  'Gado Gado: Salad Indonesia',
#  'Be Celeng Base Manis (Babi Kecap)',
#  'Kecap Manis Indonesia (Kecap Manis)',
#  'Bali Enak',
#  'Nasi Ala Indonesia Dengan Tempe',
#  'Salad Sayur Indonesia Dengan Saus Kacang (Gado-Gado)',
#  'Kubis Kari Indonesia',
#  'Gado Gado Dengan Sambal Kacang (Saus Kacang Pedas)',
#  'Munching Indonesia @ Nasi Goreng',
#  'Sparerib Indonesia',
#  'Gulai Bagar (Kari Sumatera Barat)',
#  'Tusuk Sate Ayam',
#  'Sambal Kecap',
#  'Daging Babi Panggang Indonesia',
#  'Paha Ayam Jeruk Nipis dan Anggur Indonesia',
#  'Pasta Cabai Pedas Api (Sambal) - Saus Indonesia',
#  'Tumis Babi Manis',
#  'Gulai Sayur (Kari Collard Greens ala Indonesia)',
#  'Telo ( Suriname-Indonesia)',
#  'Cara Membuat Sate Daging Sapi',
#  'Nasi Goreng Versi Saya (Nasi Goreng Indonesia)',
#  'Perawatan Sayuran',
#  'Ayam Bakar Bali',
#  'Nasi Kuning - Nasi Kuning Meriah. Nasi Indonesia Dengan Pandan..',
#  'Ayam Kunyit Panggang Indonesia',
#  'Kari Ayam ala Indonesia',
#  'Saus Kacang Indonesia',
#  'Iga Babi Dengan Sayuran yang Diawetkan',
#  'Eskrim Pokat (Makanan Penutup Cambuk Alpukat)',
#  'Tahu “Telur” Foo Yung',
#  'Daging Sapi Jeruk Pedas',
#  'Terong Bakar Ala Indonesia Dengan Saus Kacang Pedas',
#  'Tongseng Ayam Ala Yodamom',
#  'Ayam Bakar Indonesia',
#  'Ayam Bawang Putih Indonesia',
#  'Babi Pulau',
#  'Saus Sambal Indonesia',
#  'Salad Gado Gado Indonesia yang Segar dan Mudah',
#  'Nasi Kuning Indonesia',
#  'Crock Pot Ayam Indonesia',
#  'Kari Daging Sapi & Terong Indonesia',
#  'Rendang Daging Sapi Indonesia',
#  'DAGING BUMBU BALI - Hidangan daging khas Indonesia',
#  'Risoles (Risoles Gaya Indonesia)',
#  'Babi Pangang',
#  'Ayam Asia Manis Carleez',
#  'Serabi',
#  'daging rendang',
#  'Achar (Acar Cepat Indonesia)',
#  'Ayam Indonesia dari Good Housekeeping',
#  'Kari Ayam Indonesia',
#  'Lemper Indonesia Debbie',
#  'Sate Ayam (Sate Ayam)',
#  'Crock Pot Daging Sapi Indonesia',
#  'Salad Sayuran dan Tahu Dengan Saus Kacang',
#  'Daging Sapi Bawang Putih Pedas',
#  'Salad Nasi Indonesia',
#  'Rebusan Terong Sangat Enak, Piring Anda Akan Bersih!',
#  'Sambal Tahu',
#  'Sate Ayam (Sate)',
#  'Babi Pangang Indonesia',
#  'Mie Goreng Jawa (Mie Goreng Jawa)',
#  'Kari Rendang Ayam',
#  'Kacang Panggang Madu Indonesia',
#  'Salad Udang dan Alpukat dengan saus merah muda',
#  'Ayam Panggang Pedas',
#  'Sate Ayam Bakar Indonesia',
#  'Kari Babi dan Labu Indonesia',
#  'Saus Sate (Yang Asli)',
#  'Ayam Panggang',
#  'Jemput Jemput (Pisang Goreng Indonesia)',
#  'Salad Indonesia Kd Lang',
#  'Gado Gado (Sayuran Dengan Saus Kacang)',
#  'Sate rasa manis (Sate Manis)',
#  'Ayam dan Nasi Indonesia',
#  'Smoothie Pulau Rempah',
#  'Smoothie Pisang Jeruk',
#  'Ayam Javana',
#  'Kubis Goreng Ala Indonesia',
#  'Sate Ayam Bakar',
#  'Saus Salad Terinspirasi Indonesia',
#  'Kecap Manis (Kecap Manis)',
#  'Minuman Alpukat Asia yang Menyegarkan',
#  'Rijsttafel',
#  'Lemper Ayam (Nasi Ketan Dengan Isian Ayam)',
#  'Mie Goreng - Mie Goreng Indonesia',
#  'Saus Katjang (Saus Kacang Pedas)',
#  'Sup Kacang Hijau Manis',
#  'Daging Sapi Renyah',
#  'Daging Babi Panggang Indonesia dengan Saus Kacang',
#  'Daging Sapi Kelapa',
#  'Salad Nasi Indonesia Dengan Saus Jeruk-Wijen-Ketumbar',
#  'Ayam Saus Kelapa',
#  'Sayur Taucho',
#  'Pisang Goreng (Pisang Goreng Indonesia)',
#  'Pisang Goreng Indonesia',
#  'Ayam Balanese Panggang',
#  'daging rendang',
#  'Bakso Sate',
#  'Terong Indonesia Dengan Saus Kacang',
#  'Nasi Goreng Udang',
#  'Gado-Gado (Salad Sayuran Indonesia dengan Saus Kacang Pedas',
#  'Kari Nanas atau Apel Kelapa',
#  'Sop Buntot (Sup Buntut Indonesia)',
#  'Udang Sambal Pedas',
#  'Bubur Sum-Sum (Puding Nasi Indonesia)',
#  'Mie Goreng Indonesia (Mie Goreng)',
#  'Bourbon Chicken',
#  'Crock Pot Iga Pedesaan Gaya Indonesia',
#  'Dada Ayam Indonesia',
#  'Kebab Ayam Indonesia (Sate Ayam, Bumbu Saté)',
#  'Salad Terong Wijen (Terong).',
#  'Nasi Goreng Pedas',
#  'Nasi Goreng Indonesia yang Mudah (Bumbu Nasi Goreng)',
#  'Mie Goreng ala Indonesia',
#  'Salad Nasi Indonesia Terkenal Sri Wasano',
#  'Nasi Goreng Vegetarian (Nasi Goreng)',
#  'Kerang dalam Kaldu Kelapa-Jeruk Pedas',
#  'Saus Nanas Pedas',
#  'Nasi Goreng Indonesia (Ashmore dan Cartier)',
#  'Salad Sayur Campur Saus Kacang (Gado-Gado)',
#  'Jemput Jumput (Pisang Goreng)',
#  'Wortel Goreng Indonesia',
#  'Loempia Indonesia',
#  'Nasi goreng',
#  'Daging Babi Cincang Pedas Dengan Tanaman Telur',
#  'Nasi Kuning Indonesia',
#  'Salad Indonesia Dengan Saus Kacang',
#  'Kari Daging Sapi Indonesia Dengan Nasi Kelapa',
#  'Halibut Chili-Jahe',
#  'Saus Kacang Indonesia Terbaik',
#  'Saus Barbekyu Asam Jawa',
#  'Sate Daging Sapi Indonesia (Sate) Dengan Kecap Manis',
#  'Krengsengan Daging',
#  'Ayam Goreng Jawa',
#  'Udang Indonesia',
#  'Nasi goreng',
#  '"Beberapa Suka Panas"',
#  'Nasi Goreng Sederhana Dengan Jamur dan Tahu',
#  'Tahu Telur Dadar Indonesia',
#  'Sayap Ayam Indonesia',
#  'Kacang Hijau Indonesia dengan Jahe & Cabai',
#  'Kari Rendang Thailand-Indonesia',
#  'Ayam Bali (Ayam Bali)',
#  'Nasi Goreng Indonesia',
#  'Pot Kuali Ayam Kelapa Indonesia',
#  'Tempe Manis dan Pedas',
#  'Boh Pik Dipemp (Labu Aceh Bergerigi Dengan Kelapa)',
#  'Sate Indonesia',
#  'Ayam Indonesia',
#  'South China Morning Post 1963 - Tusuk Sate Ayam Asli',
#  'Bebek Betutu (Bebek Panggang ala Bali)',
#  'Udang Panggang Dengan Sambal Serai-Chili yang Berapi-api',
#  'Ayam Buruan Cornish yang Berair',
#  'Bahmi Goreng Indonesia',
#  'Mission Street Marinasi Bengkuang & Acar Jalapeno',
#  'Jagung Gosong Rebus',
#  'Macaroni Schotel (Keju Makaroni Indonesia)',
#  'Tumis Kangkong',
#  'Babi Ketjap',
#  'Nasi Kelapa Indonesia Dengan Ayam dan Zucchini',
#  'Ayam Tomat Pedas (Ayam Masak Merah)',
#  'Nasi Goreng Indonesia',
#  'Ketjap Manis',
#  'Putu Ayu (Kue Kelapa Kukus Indonesia)',
#  'Beras Indonesia',
#  'Tempe Bakar Dengan Paprika',
#  'Nasi Goreng Indonesia (Nasi Goreng)',
#  'Sambal Belacan',
#  'Kari Ayam Kelapa (kari ayam dengan kelapa panggang)',
#  'Kue Teh Pala (Kue Kering)',
#  'Kue Jagung Indonesia',
#  'Sate Babi Indonesia Pedas (Atau Ayam)',
#  'Sate Indonesia (Kebab Daging)',
#  'Sambol Goreng',
#  'Martabak Manis Indonesia',
#  'Potongan-potongan kecil pisang',
#  'Rujak Salad Buah Indonesia & Saus Jeruk Kacang Tangy',
#  'Ayam Kacang Indonesia',
#  'Mi Goreng Vegetarian (Mie Goreng Indonesia)',
#  'Pasta Bumbu Indonesia (Sambal)',
#  'Babi Indonesia',
#  'Kroket Kentang Indonesia- (Kroket Kentang)',
#  'Kari Hati Indonesia',
#  'Roti Daging Sapi Ketumbar (Sae Daging Giling)',
#  'Pakis Kari Ikan Asap',
#  'Salad Mangga',
#  'Mie Indonesia',
#  'Drum Ayam Manis',
#  'Perkedel Indonesia',
#  'Pancit Guisado Filipina (Mie Goreng dengan daging campur)',
#  'Piring Lalab Dengan Sambal Terasi',
#  'Tusuk Sate Ayam Indonesia dengan Saus Kacang (Sate Ayam)',
#  'Ayam Saus Kacang',
#  'Ayam Crock-Pot "Asia" Laura',
#  'Salad Mentimun Indonesia',
#  'Nasi Goreng: Nasi Goreng Indonesia',
#  'Pasta Kacang Jawa',
#  'Perkedel Resep Asli Indonesia',
#  'Bami Goreng (Lo Mein Versi Indonesia)',
#  'Serundeng Indonesia (Kelapa Bumbu Renyah dengan Kacang)',
#  'Terong Pedas (Terong Balado)',
#  'Salad Mentimun Asam Manis',
#  'Fillet Daging Sapi dalam Kelapa',
#  'Sate Daging Sapi ala Jawa',
#  'Atjar Ketimun (Mentimun dalam Kunyit)',
#  'Kari Kacang dan Nanas',
#  'Udang Bakar yang Mudah dan Nikmat',
#  'Kaya (Puding Telur Kelapa)',
#  'Sambal Cabai Goreng',
#  'Telur Balado (Saus Cabai Pedas dengan Telur)',
#  'Brokoli Ayam Ca - Gaya Unieng',
#  'Rendang Daging Sapi Indonesia (Rendang Sapi)',
#  'Ikan Bakar dengan Rempah-rempah',
#  'Sate Babi (Atau Ayam)',
#  'Udang Dengan Saus Kacang',
#  'Udang Renyah ala Sulawesi',
#  'Tuna dengan belimbing dan cabai',
#  'Roti Daging Sapi Indonesia',
#  'Spekkoek (Lapis Sah)',
#  'Kacang Hijau dengan Kacang Tanah',
#  'Salad Mentimun (Acar Ketimun)',
#  'Sup Udang Kari dan Sayur',
#  'Minuman Mentimun ala Aceh Alias Es Timun Aceh',
#  'Kari Daging Sapi Indonesia',
#  'Chutney Mangga Laurel',
#  'Nasi Goreng Indonesia - Nasi Goreng',
#  'Udang Kelapa Dengan Kecap Manis dan Saus Cabai',
#  'Nasi Bumbu Indonesia',
#  'Pie Daun Bawang Indonesia',
#  'Tahu dan Mie Kacang',
#  'Kue Cokelat Chip "Indonesia".',
#  'Ayam Indonesia Saus Lengkuas-Tomat',
#  'Saus Kacang Indonesia',
#  'Ayam Jahe Indonesia',
#  'Bola Daging Kelapa Indonesia',
#  'Nasi Kelapa Indonesia',
#  'Puding Roti Meringue Nanas',
#  'Bakso Indonesia',
#  'Perkedel Jagung (Jagung Goreng Indonesia)',
#  'Ayam Goreng (Ayam Goreng) - Gaya Indonesia',
#  'Kue Pisang Jeruk Dengan Sirup Jeruk',
#  'Sambal Oelek - Bumbu',
#  'Tenderloin Babi Indonesia',
#  'Daging Sapi Pedas dalam Kelapa (Rendang Daging Sapi)',
#  'Pisang Goreng Indonesia (Pisang Goreng)',
#  'Dadih Kelapa | Kaya (Singapura)',
#  'Saus Tomat & Cabai',
#  'Kacang Panjang Kecap - Kacang Hijau Indonesia dengan Kedelai Manis',
#  'Nasi Goreng Indonesia (Nasi Goreng)',
#  'Mie Wijen Indonesia',
#  'Pancake Pisang, Resep Wayan',
#  'Ayam Indonesia, Saus Selai Kacang (Slow Cooker)',
#  'Salmon Indonesia',
#  'Tempe Rebus Hoisin dan Sayuran Cina',
#  'Pasta Cabai Pedas (Sambal) - Saus Indonesia',
#  'Tusuk Sate Ayam Dengan Saus Sate']

# %%
iter = 0
for i in data2['nama_makanan']: 
    if i == "Ayam Bakar Indonesia": 
        print(iter)
        break
    iter += 1
# Out:
# 21

# %%
# print(len(reconstructed_model.predict(x_test)))
reconstructed_model.predict(np.array([[1000,21]])) * 5
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# array([[3.638805]], dtype=float32)
